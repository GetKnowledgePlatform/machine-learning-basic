# %% [markdown]
# # Pandas - In memory database

# %% [markdown]
# ![Pandas!](./pandas.jpeg)

# %% [markdown]
# ## Dataset
# Мы будем работать с ценами акций компаний, которые входят в S&P 500 индекс.
#
# https://www.kaggle.com/datasets/camnugent/sandp500

# %%
# !head sp500.csv
# Out:
# date,open,high,low,close,volume,Name
# 2013-02-08,15.07,15.12,14.63,14.75,8407500,AAL
# 2013-02-11,14.89,15.01,14.26,14.46,8882000,AAL
# 2013-02-12,14.45,14.51,14.1,14.27,8126000,AAL
# 2013-02-13,14.3,14.94,14.25,14.66,10259500,AAL
# 2013-02-14,14.94,14.96,13.16,13.99,31879900,AAL
# 2013-02-15,13.93,14.61,13.93,14.5,15628000,AAL
# 2013-02-19,14.33,14.56,14.08,14.26,11354400,AAL
# 2013-02-20,14.17,14.26,13.15,13.33,14725200,AAL
# 2013-02-21,13.62,13.95,12.9,13.37,11922100,AAL

# %% [markdown]
# # Подключение библиотеки в проект

# %%
import pandas as pd

# %% [markdown]
# # Чтение данных

# %%
df = pd.read_csv('sp500.csv')

# %%
pd.read_csv?

# %%
df.head()
# Out:
#          date   open   high    low  close    volume Name
# 0  2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1  2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2  2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3  2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4  2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL

# %% [markdown]
# # Информация о dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 619040 entries, 0 to 619039
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    619040 non-null  object
#  1   open    619029 non-null  float64
#  2   high    619032 non-null  float64
#  3   low     619032 non-null  float64
#  4   close   619040 non-null  float64
#  5   volume  619040 non-null  int64
#  6   Name    619040 non-null  object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 33.1+ MB

# %%
df.describe()
# Out:
#                 open           high            low          close  \
# count  619029.000000  619032.000000  619032.000000  619040.000000
# mean       83.023334      83.778311      82.256096      83.043763
# std        97.378769      98.207519      96.507421      97.389748
# min         1.620000       1.690000       1.500000       1.590000
# 25%        40.220000      40.620000      39.830000      40.245000
# 50%        62.590000      63.150000      62.020000      62.620000
# 75%        94.370000      95.180000      93.540000      94.410000
# max      2044.000000    2067.990000    2035.110000    2049.000000
#
#              volume
# count  6.190400e+05
# mean   4.321823e+06
# std    8.693610e+06
# min    0.000000e+00
# 25%    1.070320e+06
# 50%    2.082094e+06
# 75%    4.284509e+06
# max    6.182376e+08

# %%
df.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'Name'], dtype='object')

# %%
df.shape
# Out:
# (619040, 7)

# %%
df['Name']
# Out:
# 0         AAL
# 1         AAL
# 2         AAL
# 3         AAL
# 4         AAL
#          ...
# 619035    ZTS
# 619036    ZTS
# 619037    ZTS
# 619038    ZTS
# 619039    ZTS
# Name: Name, Length: 619040, dtype: object

# %%
df['Name'].value_counts()
# Out:
# AAL     1259
# NRG     1259
# NOC     1259
# NLSN    1259
# NKE     1259
#         ...
# DXC      215
# BHGE     152
# BHF      143
# DWDP     109
# APTV      44
# Name: Name, Length: 505, dtype: int64

# %% [markdown]
# # Индексация

# %%
df['low']
# Out:
# 0         14.63
# 1         14.26
# 2         14.10
# 3         14.25
# 4         13.16
#           ...
# 619035    76.69
# 619036    76.73
# 619037    73.18
# 619038    72.13
# 619039    72.69
# Name: low, Length: 619040, dtype: float64

# %%
df['low'].describe()
# Out:
# count    619032.000000
# mean         82.256096
# std          96.507421
# min           1.500000
# 25%          39.830000
# 50%          62.020000
# 75%          93.540000
# max        2035.110000
# Name: low, dtype: float64

# %%
type(df['low'])
# Out:
# pandas.core.series.Series

# %%
df[['high','low']]
# Out:
#          high    low
# 0       15.12  14.63
# 1       15.01  14.26
# 2       14.51  14.10
# 3       14.94  14.25
# 4       14.96  13.16
# ...       ...    ...
# 619035  78.27  76.69
# 619036  78.12  76.73
# 619037  76.92  73.18
# 619038  74.56  72.13
# 619039  75.00  72.69
#
# [619040 rows x 2 columns]

# %%
df.iloc[1]
# Out:
# date      2013-02-11
# open           14.89
# high           15.01
# low            14.26
# close          14.46
# volume       8882000
# Name             AAL
# Name: 1, dtype: object

# %%
df.iloc[1:5]
# Out:
#          date   open   high    low  close    volume Name
# 1  2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2  2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3  2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4  2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL

# %%
df.iloc[1:5,:3]
# Out:
#          date   open   high
# 1  2013-02-11  14.89  15.01
# 2  2013-02-12  14.45  14.51
# 3  2013-02-13  14.30  14.94
# 4  2013-02-14  14.94  14.96

# %%
df.iloc[2,1]
# Out:
# 14.45

# %% [markdown]
# # Sort

# %%
sorted_df = df.sort_values(['close'], ascending=0)
# df.sort_values(['close'], inplace=True)
# Out:
#               date     open     high      low    close    volume  Name
# 441193  2017-08-08  2044.00  2067.99  2035.11  2049.00    830572  PCLN
# 441192  2017-08-07  2034.73  2044.51  2022.00  2042.64    402270  PCLN
# 441184  2017-07-26  2019.24  2037.00  2017.56  2033.21    311753  PCLN
# 441191  2017-08-04  2031.02  2035.47  2020.29  2032.77    333534  PCLN
# 441187  2017-07-31  2030.00  2033.00  2010.24  2028.50    503331  PCLN
# ...            ...      ...      ...      ...      ...       ...   ...
# 39451   2015-07-24     1.76     1.77     1.65     1.67  16478376   AMD
# 39496   2015-09-28     1.69     1.70     1.66     1.66   5693063   AMD
# 39473   2015-08-25     1.82     1.82     1.66     1.66  12097696   AMD
# 39452   2015-07-27     1.67     1.70     1.61     1.62  11916468   AMD
# 115059  2016-02-12     1.86     1.89     1.56     1.59  49579181   CHK
#
# [619040 rows x 7 columns]

# %%
df
# Out:
#               date   open   high    low  close    volume Name
# 0       2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1       2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2       2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3       2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4       2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL
# ...            ...    ...    ...    ...    ...       ...  ...
# 619035  2018-02-01  76.84  78.27  76.69  77.82   2982259  ZTS
# 619036  2018-02-02  77.53  78.12  76.73  76.78   2595187  ZTS
# 619037  2018-02-05  76.64  76.92  73.18  73.83   2962031  ZTS
# 619038  2018-02-06  72.74  74.56  72.13  73.27   4924323  ZTS
# 619039  2018-02-07  72.70  75.00  72.69  73.86   4534912  ZTS
#
# [619040 rows x 7 columns]

# %% [markdown]
# # Изменение колонки

# %%
df['delta'] = df['close']-df['open']

# %%
df
# Out:
#               date   open   high    low  close    volume Name  delta
# 0       2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL  -0.32
# 1       2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL  -0.43
# 2       2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL  -0.18
# 3       2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL   0.36
# 4       2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL  -0.95
# ...            ...    ...    ...    ...    ...       ...  ...    ...
# 619035  2018-02-01  76.84  78.27  76.69  77.82   2982259  ZTS   0.98
# 619036  2018-02-02  77.53  78.12  76.73  76.78   2595187  ZTS  -0.75
# 619037  2018-02-05  76.64  76.92  73.18  73.83   2962031  ZTS  -2.81
# 619038  2018-02-06  72.74  74.56  72.13  73.27   4924323  ZTS   0.53
# 619039  2018-02-07  72.70  75.00  72.69  73.86   4534912  ZTS   1.16
#
# [619040 rows x 8 columns]

# %%
df.drop(columns=['delta'])
# Out:
#               date   open   high    low  close    volume Name
# 0       2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1       2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2       2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3       2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4       2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL
# ...            ...    ...    ...    ...    ...       ...  ...
# 619035  2018-02-01  76.84  78.27  76.69  77.82   2982259  ZTS
# 619036  2018-02-02  77.53  78.12  76.73  76.78   2595187  ZTS
# 619037  2018-02-05  76.64  76.92  73.18  73.83   2962031  ZTS
# 619038  2018-02-06  72.74  74.56  72.13  73.27   4924323  ZTS
# 619039  2018-02-07  72.70  75.00  72.69  73.86   4534912  ZTS
#
# [619040 rows x 7 columns]

# %% [markdown]
# # Saving

# %%
df.to_csv('modified.csv', index=False, sep='\t')

# %%
# !head modified.csv
# Out:
# date	open	high	low	close	volume	Name	delta
# 2013-02-08	15.07	15.12	14.63	14.75	8407500	AAL	-0.3200000000000003
# 2013-02-11	14.89	15.01	14.26	14.46	8882000	AAL	-0.4299999999999997
# 2013-02-12	14.45	14.51	14.1	14.27	8126000	AAL	-0.17999999999999972
# 2013-02-13	14.3	14.94	14.25	14.66	10259500	AAL	0.35999999999999943
# 2013-02-14	14.94	14.96	13.16	13.99	31879900	AAL	-0.9499999999999993
# 2013-02-15	13.93	14.61	13.93	14.5	15628000	AAL	0.5700000000000003
# 2013-02-19	14.33	14.56	14.08	14.26	11354400	AAL	-0.07000000000000028
# 2013-02-20	14.17	14.26	13.15	13.33	14725200	AAL	-0.8399999999999999
# 2013-02-21	13.62	13.95	12.9	13.37	11922100	AAL	-0.25

# %%
# !rm modified.csv

# %% [markdown]
# # Filtering

# %%
df['Name'].unique()
# Out:
# array(['AAL', 'AAPL', 'AAP', 'ABBV', 'ABC', 'ABT', 'ACN', 'ADBE', 'ADI',
#        'ADM', 'ADP', 'ADSK', 'ADS', 'AEE', 'AEP', 'AES', 'AET', 'AFL',
#        'AGN', 'AIG', 'AIV', 'AIZ', 'AJG', 'AKAM', 'ALB', 'ALGN', 'ALK',
#        'ALLE', 'ALL', 'ALXN', 'AMAT', 'AMD', 'AME', 'AMGN', 'AMG', 'AMP',
#        'AMT', 'AMZN', 'ANDV', 'ANSS', 'ANTM', 'AON', 'AOS', 'APA', 'APC',
#        'APD', 'APH', 'APTV', 'ARE', 'ARNC', 'ATVI', 'AVB', 'AVGO', 'AVY',
#        'AWK', 'AXP', 'AYI', 'AZO', 'A', 'BAC', 'BAX', 'BA', 'BBT', 'BBY',
#        'BDX', 'BEN', 'BF.B', 'BHF', 'BHGE', 'BIIB', 'BK', 'BLK', 'BLL',
#        'BMY', 'BRK.B', 'BSX', 'BWA', 'BXP', 'CAG', 'CAH', 'CAT', 'CA',
#        'CBG', 'CBOE', 'CBS', 'CB', 'CCI', 'CCL', 'CDNS', 'CELG', 'CERN',
#        'CFG', 'CF', 'CHD', 'CHK', 'CHRW', 'CHTR', 'CINF', 'CI', 'CLX',
#        'CL', 'CMA', 'CMCSA', 'CME', 'CMG', 'CMI', 'CMS', 'CNC', 'CNP',
#        'COF', 'COG', 'COL', 'COO', 'COP', 'COST', 'COTY', 'CPB', 'CRM',
# ...

# %%
df['Name']=='IBM'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 619035    False
# 619036    False
# 619037    False
# 619038    False
# 619039    False
# Name: Name, Length: 619040, dtype: bool

# %%
df[(df['Name']=='IBM') & (df['delta'] < 0)]
# Out:
#               date    open    high       low   close   volume Name  delta
# 290492  2013-02-11  200.98  201.95  199.7500  200.16  2944651  IBM  -0.82
# 290494  2013-02-13  200.65  200.95  199.5700  200.09  2169757  IBM  -0.56
# 290495  2013-02-14  199.73  200.32  199.2600  199.65  3294126  IBM  -0.08
# 290497  2013-02-19  200.60  201.89  200.2200  200.32  2998317  IBM  -0.28
# 290498  2013-02-20  200.62  201.72  198.8600  199.31  3715311  IBM  -1.31
# ...            ...     ...     ...       ...     ...      ...  ...    ...
# 291744  2018-01-31  163.75  164.99  162.7610  163.70  4072830  IBM  -0.05
# 291745  2018-02-01  163.19  164.13  161.9000  162.40  4434242  IBM  -0.79
# 291746  2018-02-02  161.70  162.00  158.8663  159.03  5251938  IBM  -2.67
# 291747  2018-02-05  157.89  158.50  150.0000  152.53  8746599  IBM  -5.36
# 291749  2018-02-07  154.17  155.34  153.2800  153.85  6149207  IBM  -0.32
#
# [614 rows x 8 columns]

# %% [markdown]
# # Group by

# %%
df.groupby('Name').sum(numeric_only=True)
# Out:
#              open         high          low        close       volume    delta
# Name
# A      61927.5200   62446.4739   61416.5707   61945.3500   2943590983  17.8300
# AAL    48333.6338   49045.0423   47622.4367   48337.1046  11822414547   3.4708
# AAP   166741.4949  168477.2362  164974.3554  166733.7300   1357256410  -7.7649
# AAPL  137300.7850  138428.4580  136150.2604  137314.9734  68046305767  14.1884
# ABBV   76550.7260   77395.9335   75763.1891   76628.3300   9909189476  77.6040
# ...           ...          ...          ...          ...          ...      ...
# XYL    52142.0801   52580.7312   51714.7172   52165.5250   1489574691  23.4449
# YUM    94956.4223   95718.1484   94229.7471   94992.8200   4040170774  36.3977
# ZBH   132877.3950  133982.5966  131814.8301  132958.3200   1633103868  80.9250
# ZION   40491.2997   40929.1958   40039.0216   40504.2840   3300062992  12.9843
# ZTS    56770.0587   57270.4322   56233.9759   56779.1980   4635485010   9.1393
#
# ...

# %%
df.groupby('Name').count()
# Out:
#       date  open  high   low  close  volume  delta
# Name
# A     1259  1259  1259  1259   1259    1259   1259
# AAL   1259  1259  1259  1259   1259    1259   1259
# AAP   1259  1259  1259  1259   1259    1259   1259
# AAPL  1259  1259  1259  1259   1259    1259   1259
# ABBV  1259  1259  1259  1259   1259    1259   1259
# ...    ...   ...   ...   ...    ...     ...    ...
# XYL   1259  1259  1259  1259   1259    1259   1259
# YUM   1259  1259  1259  1259   1259    1259   1259
# ZBH   1259  1259  1259  1259   1259    1259   1259
# ZION  1259  1259  1259  1259   1259    1259   1259
# ZTS   1259  1259  1259  1259   1259    1259   1259
#
# [505 rows x 7 columns]

# %%
df.groupby('Name').min()['delta'].loc['AAPL']
# Out:
# -7.3700000000000045

# %%
df.groupby('Name').max()['delta'].loc['AAPL']
# Out:
# 8.25

# %% [markdown]
# # Graphic

# %%
# %matplotlib inline
df[df['Name']=='IBM'].plot(x="date", y=["close","open"])
# Out:
# <AxesSubplot: xlabel='date'>
