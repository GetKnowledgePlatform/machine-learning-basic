# %% [markdown]
# # Uncertainty / Неопредленность
# ![](./uncertainty.jpeg)

# %% [markdown]
# # Probability
#
# ![](./probability.png)
#
#
# - Вероятнсоть изменяется от 0..1
# - 0 - невозможное событие
# - 1 - тождественное событие
# - обратная вероятность (1-p)
# - сумма всех независимых событий в итоге должна дать 1

# %% [markdown]
# # Random Value
#
# ![](./height.webp)

# %% [markdown]
# # Distribution Discrete
# ![](./car_colors.gif)

# %% [markdown]
# # Distribution Continious
#
# ![](./normal-distrubution.svg)

# %% [markdown]
# # Uniform
# ![](./uniform.png)

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

values = np.random.uniform(-10.0, 10.0, 100_000)
plt.hist(values, 50)
plt.show()

# %% [markdown]
# # Normal / Gaussian
# ![](./gaussian.jpeg)

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt

x = np.arange(-3, 3, 0.001)
plt.plot(x, norm.pdf(x))

# %%
import numpy as np
import matplotlib.pyplot as plt

mu = 150.0
sigma = 150.0
values = np.random.normal(mu, sigma, 10_000)
plt.hist(values, 50)
plt.show()

# %% [markdown]
# # Exponential

# %%
from scipy.stats import expon
import matplotlib.pyplot as plt

x = np.arange(0, 10, 0.001)
plt.plot(x, expon.pdf(x))
